# %%
# These notes are compiled from the book Python Data Science Handbook by Jake VanderPlas
# https://jakevdp.github.io/PythonDataScienceHandbook/

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
plt.style.use('classic')

# %%
x = np.linspace(0.1, 10, 110)
fi = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');
#fi.savefig('my_figure.png')
#saves figure to file

# %%
from IPython.display import Image
Image('my_figure.png')

# %%
fi.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
#object-oriented interface

fig, ax = plt.subplots(2)
ax[0].plot(x, x**2)
ax[1].plot(x, x**-1)

# %%
plt.style.use('seaborn-whitegrid')
plt.plot(x,np.sin(x), color ='red') #pylab interface - no need to create fig and axes
plt.plot(x, np.cos(x)); #will only allow 1 axes at a time though

# %%
# Changing colors

# plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
# plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
# plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
# plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
# plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
# plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

#Changing line styles

# plt.plot(x, x + 0, linestyle='solid')
# plt.plot(x, x + 1, linestyle='dashed')
# plt.plot(x, x + 2, linestyle='dashdot')
# plt.plot(x, x + 3, linestyle='dotted');
# # For short, you can use the following codes:
# plt.plot(x, x + 4, linestyle='-')  # solid
# plt.plot(x, x + 5, linestyle='--') # dashed
# plt.plot(x, x + 6, linestyle='-.') # dashdot
# plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
y = np.linspace(-100, 100, 10000)
plt.plot(y, y**2)
plt.xlim(-10, 20)
plt.ylim(-5, 100)
# alternatively, plt.axis([xmin, xmax, ymin, ymax]) can be used to set axes limits as well
# Out:
# (-5, 100)

# %%
plt.plot(x, x**2)
#plt.axis('equal') #x and y axis equal scale
plt.axis('tight') #bounds axes around plot
# Out:
# (0.1, 10.0, 0.010000000000000002, 100.0)

# %%
plt.plot(x, np.sin(x), '-.g', label='sine curve')
plt.plot(x, x**2, '--r', label = 'quadratic curve')
plt.title('line summary')
plt.xlabel('x axis')
plt.ylabel('y not')
plt.legend()
#https://jakevdp.github.io/PythonDataScienceHandbook/04.06-customizing-legends.html

# %%
#object oriented interface to plotting
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %%
#Scatter Plots

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker), markersize=15)
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
y=np.random.rand(len(x))
plt.scatter(x, y, marker = 's' , color = 'red')

# %%
c = np.linspace(0, 5, 110)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=c, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar()

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

#Gives us 4 dimensions to the data
#(x, y) location of each point corresponds to the sepal length and width, the size of the point is related to the petal width, and the color is related to the particular species of flower
